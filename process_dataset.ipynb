# %% [markdown]
# # Process astreroids dataset
# Written by Kiyoaki Okudaira<br>
# *Kyushu University Hanada Lab / University of Washington / IAU CPS SatHub<br>
# (okudaira.kiyoaki.528@s.kyushu-u.ac.jp or kiyoaki@uw.edu)<br>
# <br>
# Process asteroids data set from NASA SENTRY / ESA AEGIS API and make asteroid event lists with IP from both data set.<br>
# <br>
# **History**<br>
# coding 2026-02-03 : 1st coding<br>
# update 2026-02-13 : Add velocity infinity<br>
# <br>
# This code is written for University of Washington ASTR 302 WINTER 2026 Project NEO.<br>
# (c) 2026 Kiyoaki Okudaira - Kyushu University Hanada Lab (SSDL) / University of Washington / IAU CPS SatHub

# %% [markdown]
# ### Parameters

# %%
event_range = 7 # time range considered to be the same event [day] | int

# %% [markdown]
# ### Import and initial settings
# **PATH settings**

# %%
base_PATH = "/Users/kiyoaki/VScode/ASTR302_projectNEO/"
output_PATH = base_PATH + "data"

# %% [markdown]
# **Standard libraries**

# %%
import pickle
from astropy.table import Table
from datetime import datetime, timedelta
import math
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### NASA SENTRY Dataset
# **Import dataset**

# %%
with open(f'{output_PATH}/workspace_NASA_table.pkl', "rb") as f:
    NASA_table = pickle.load(f)
NASA_table = NASA_table.group_by("des")
NASA_table
# Out:
# <Table length=44319>
#         fullname           des        ip    ...   ts       v_inf
#          str24            str10    float64  ... int64     float64
# ------------------------ -------- --------- ... ----- ----------------
# 101955 Bennu (1999 RQ36)   101955     1e-07 ...    --  5.9916984432395
# 101955 Bennu (1999 RQ36)   101955     1e-07 ...    --  5.9916984432395
# 101955 Bennu (1999 RQ36)   101955     1e-07 ...    --  5.9916984432395
# 101955 Bennu (1999 RQ36)   101955     1e-07 ...    --  5.9916984432395
# 101955 Bennu (1999 RQ36)   101955     1e-07 ...    --  5.9916984432395
# 101955 Bennu (1999 RQ36)   101955     1e-07 ...    --  5.9916984432395
# 101955 Bennu (1999 RQ36)   101955     1e-07 ...    --  5.9916984432395
# 101955 Bennu (1999 RQ36)   101955     1e-07 ...    --  5.9916984432395
# 101955 Bennu (1999 RQ36)   101955     1e-07 ...    --  5.9916984432395
#                      ...      ...       ... ...   ...              ...
#               (2026 CU1) 2026 CU1 3.005e-08 ...     0 8.13169141778632
#               (2026 CU1) 2026 CU1 2.523e-05 ...     0 8.13169141778632
#               (2026 CU1) 2026 CU1 1.266e-06 ...     0 8.13169141778632
#               (2026 CU1) 2026 CU1 4.755e-06 ...     0 8.13169141778632
#               (2026 CU1) 2026 CU1 3.547e-07 ...     0 8.13169141778632
#               (2026 CU1) 2026 CU1 5.066e-08 ...     0 8.13169141778632
#               (2026 CU1) 2026 CU1 3.718e-07 ...     0 8.13169141778632
#          29075 (1950 DA)    29075  0.000377 ...    --             14.1
#       443104 (2013 XK22)   443104 4.456e-06 ...     0              6.9
#        620100 (2016 WJ1)   620100 7.676e-06 ...     0            14.85

# %% [markdown]
# **Date handling**<br>
# Round down date and format "YYYY-MM-DD"

# %%
NASA_table["date-round"] = "0000-00-00"
for row in NASA_table:
    dates = row["date"].split("-")
    row["date-round"] = dates[0] + "-" + dates[1] + "-" + str(math.floor(float(dates[2]))).zfill(2)

# %% [markdown]
# **Sum impact probability**<br>
# Compute impact probability of an asteroid for a same date

# %%
dess = []
full_names = []
dates = []
ips = []
des_chrs = []
des_nums = []
v_infs = []

for object in NASA_table.groups:
    date_groups = object.group_by("date-round")
    for date_group in date_groups.groups:
        dess.append(date_group[0]["des"])
        full_names.append(date_group[0]["fullname"])
        dates.append(date_group[0]["date-round"])
        ips.append(date_group["ip"].sum())
        des_chr = date_group[0]["fullname"].split("(")[-1][0:-1]
        des_chrs.append(des_chr.replace(" ",""))
        v_infs.append(date_group[0]["v_inf"])
        if des_chr == date_group[0]["des"]:
            des_nums.append(None)
        else:
            des_nums.append(date_group[0]["des"])

NASA_cum_ip_date_table = Table({
    "des_chr": des_chrs,
    "des_num": des_nums,
    "des": dess,
    "fullname": full_names,
    "date": dates,
    "cum_ip": ips,
    "v_inf": v_infs
})
# NASA_cum_ip_date_table

# %% [markdown]
# Compute impact probability of an asteroid for near-by date

# %%
dess = []
full_names = []
date_starts = []
date_ends = []
ips = []
des_chrs = []
des_nums = []
v_infs = []

NASA_cum_ip_table = NASA_cum_ip_date_table.group_by("des")
for object in NASA_cum_ip_table.groups:
    object.sort("date")
    former_date = None
    for row in object:
        if former_date is None:
            des_chrs.append(row["des_chr"])
            des_nums.append(row["des_num"])
            v_infs.append(row["v_inf"])
            dess.append(row["des"])
            full_names.append(row["fullname"])
            date_starts.append(row["date"])
            date_ends.append(row["date"])
            ips.append(row["cum_ip"])
            former_date = datetime.strptime(row["date"],'%Y-%m-%d')
        elif datetime.strptime(row["date"],'%Y-%m-%d') < former_date + timedelta(days=event_range):
            ips[-1] = ips[-1] + row["cum_ip"]
            former_date = datetime.strptime(row["date"],'%Y-%m-%d')
            date_ends[-1] = row["date"]
        else:
            des_chrs.append(row["des_chr"])
            des_nums.append(row["des_num"])
            v_infs.append(row["v_inf"])
            dess.append(row["des"])
            full_names.append(row["fullname"])
            date_starts.append(row["date"])
            date_ends.append(row["date"])
            ips.append(row["cum_ip"])
            former_date = datetime.strptime(row["date"],'%Y-%m-%d')

NASA_cum_ip_table = Table({
    "des_chr": des_chrs,
    "des_num": des_nums,
    "des": dess,
    "fullname": full_names,
    "date_start": date_starts,
    "date_end": date_ends,
    "cum_ip": ips,
    "v_inf": v_infs
})

NASA_cum_ip_table.sort("des_chr")
NASA_cum_ip_table.group_by("des_chr")

NASA_cum_ip_table.write(f'{output_PATH}/NASA_cum_ip_table.csv', overwrite = True)
with open(f'{output_PATH}/workspace_NASA_cum_ip_table.pkl', 'wb') as f:
    pickle.dump(NASA_cum_ip_table, f)

NASA_cum_ip_table
# Out:
# <Table length=22326>
# des_chr des_num   des    ...  date_end          cum_ip              v_inf
#   str9   object  str10   ...   str10           float64             float64
# ------- ------- -------- ... ---------- ---------------------- ----------------
#  1950DA   29075    29075 ... 2880-03-16               0.000377             14.1
#  1979XB    None  1979 XB ... 2113-12-14              5.532e-07 23.7606234552547
#  1979XB    None  1979 XB ... 2102-12-16              1.158e-10 23.7606234552547
#  1979XB    None  1979 XB ... 2086-12-16              1.067e-07 23.7606234552547
#  1979XB    None  1979 XB ... 2056-12-12              1.915e-07 23.7606234552547
#  1991BA    None  1991 BA ... 2051-01-18              2.354e-08 16.7227981196217
#  1991BA    None  1991 BA ... 2027-01-19              2.107e-09 16.7227981196217
#  1991BA    None  1991 BA ... 2073-01-19              1.815e-07 16.7227981196217
#  1991BA    None  1991 BA ... 2075-01-20           1.361548e-07 16.7227981196217
#     ...     ...      ... ...        ...                    ...              ...
# 2026CU1    None 2026 CU1 ... 2079-03-01 2.2152100000000003e-06 8.13169141778632
# 2026CU1    None 2026 CU1 ... 2076-02-29             2.1982e-06 8.13169141778632
# 2026CU1    None 2026 CU1 ... 2071-03-01 0.00014184699999999999 8.13169141778632
# 2026CU1    None 2026 CU1 ... 2069-03-01 2.6496000000000002e-05 8.13169141778632
# 2026CU1    None 2026 CU1 ... 2063-03-02              2.705e-07 8.13169141778632
# 2026CU1    None 2026 CU1 ... 2053-03-01             5.1097e-06 8.13169141778632
# 2026CU1    None 2026 CU1 ... 2045-03-01               8.84e-07 8.13169141778632
# 2026CU1    None 2026 CU1 ... 2039-03-02               1.49e-06 8.13169141778632
# 2026CU1    None 2026 CU1 ... 2081-03-01            2.21239e-06 8.13169141778632
# 2026CU1    None 2026 CU1 ... 2061-03-01              9.618e-07 8.13169141778632

# %% [markdown]
# ### ESA AEGIS Dataset
# **Import dataset**

# %%
with open(f'{output_PATH}/workspace_ESA_table.pkl', "rb") as f:
    ESA_table = pickle.load(f)
ESA_table = ESA_table.group_by("des")
ESA_table
# Out:
# <Table length=32691>
#   des     name   diameter_m diameter_estimated ... exp_energy_mt    ps     ts
#   str9    str8    float64          str5        ...    float64    float64 int64
# ------- -------- ---------- ------------------ ... ------------- ------- -----
#  1979XB       --      500.0               True ...       55600.0   -2.82     0
#  1979XB       --      500.0               True ...       12100.0   -5.39     0
#  1979XB       --      500.0               True ...       24900.0    -5.3     0
#  1979XB       --      500.0               True ...       17800.0   -3.33     0
#  1991BA       --        6.0               True ...        0.0197   -8.31     0
#  1991BA       --        6.0               True ...        0.0047   -9.07     0
#  1991BA       --        6.0               True ...       0.00933   -7.16     0
#  1991BA       --        6.0               True ...        0.0105   -8.23     0
#  1991BA       --        6.0               True ...       0.00415  -10.82     0
#     ...      ...        ...                ... ...           ...     ...   ...
# 2026BS7       --       17.0               True ...         0.188   -9.02     0
# 2026BS7       --       17.0               True ...         0.179   -7.36     0
# 2026BS7       --       17.0               True ...         0.187   -9.66     0
# 2026BS7       --       17.0               True ...         0.187   -9.81     0
# 2026BS7       --       17.0               True ...         0.188   -9.86     0
# 2026BS7       --       17.0               True ...         0.179   -8.56     0
# 2026BZ5       --        1.4               True ...      5.68e-05  -12.98     0
# 2026BZ5       --        1.4               True ...      5.67e-05  -11.73     0
#  443104 2013XK22       50.0               True ...          3.45   -5.85     0
#  443104 2013XK22       50.0               True ...          3.45   -8.38     0

# %% [markdown]
# **Date handling**<br>
# Round down date and format "YYYY-MM-DD"

# %%
ESA_table["date-round"] = "0000-00-00"
for row in ESA_table:
    dates = row["date"].split("-")
    row["date-round"] = dates[0] + "-" + dates[1] + "-" + str(math.floor(float(dates[2]))).zfill(2)

# %% [markdown]
# **Sum impact probability**<br>
# Compute impact probability of an asteroid for a same date

# %%
dess = []
full_names = []
dates = []
ips = []
des_chrs = []
des_nums = []

for object in ESA_table.groups:
    date_groups = object.group_by("date-round")
    for date_group in date_groups.groups:
        dess.append(date_group[0]["des"])
        full_names.append(date_group[0]["name"])
        dates.append(date_group[0]["date-round"])
        ips.append(date_group["p_re"].sum())
        try:
            date_group[0]["name"].mask
            des_chrs.append(date_group[0]["des"])
            des_nums.append(None)
        except:
            des_chrs.append(date_group[0]["name"])
            des_nums.append(date_group[0]["des"])

ESA_cum_ip_date_table = Table({
    "des_chr": des_chrs,
    "des_num": des_nums,
    "des": dess,
    "name": full_names,
    "date": dates,
    "cum_ip": ips,
})
# ESA_cum_ip_date_table

# %% [markdown]
# Compute impact probability of an asteroid for near-by date

# %%
dess = []
full_names = []
date_starts = []
date_ends = []
ips = []
des_chrs = []
des_nums = []

ESA_cum_ip_table = ESA_cum_ip_date_table.group_by("des")
for object in ESA_cum_ip_table.groups:
    object.sort("date")
    former_date = None
    for row in object:
        if former_date is None:
            des_chrs.append(row["des_chr"])
            des_nums.append(row["des_num"])
            dess.append(row["des"])
            full_names.append(row["name"])
            date_starts.append(row["date"])
            date_ends.append(row["date"])
            ips.append(row["cum_ip"])
            former_date = datetime.strptime(row["date"],'%Y-%m-%d')
        elif datetime.strptime(row["date"],'%Y-%m-%d') < former_date + timedelta(days=event_range):
            ips[-1] = ips[-1] + row["cum_ip"]
            former_date = datetime.strptime(row["date"],'%Y-%m-%d')
            date_ends[-1] = row["date"]
        else:
            des_chrs.append(row["des_chr"])
            des_nums.append(row["des_num"])
            dess.append(row["des"])
            full_names.append(row["name"])
            date_starts.append(row["date"])
            date_ends.append(row["date"])
            ips.append(row["cum_ip"])
            former_date = datetime.strptime(row["date"],'%Y-%m-%d')

ESA_cum_ip_table = Table({
    "des_chr": des_chrs,
    "des_num": des_nums,
    "des": dess,
    "name": full_names,
    "date_start": date_starts,
    "date_end": date_ends,
    "cum_ip": ips,
})

ESA_cum_ip_table.sort("des_chr")
ESA_cum_ip_table.group_by("des_chr")

ESA_cum_ip_table.write(f'{output_PATH}/ESA_cum_ip_table.csv', overwrite = True)
with open(f'{output_PATH}/workspace_ESA_cum_ip_table.pkl', 'wb') as f:
    pickle.dump(ESA_cum_ip_table, f)

ESA_cum_ip_table
# Out:
# <Table length=18106>
# des_chr des_num   des   name date_start  date_end          cum_ip
#   str9   object   str9  str8   str10      str10           float64
# ------- ------- ------- ---- ---------- ---------- ----------------------
#  1979XB    None  1979XB   -- 2056-12-12 2056-12-12               2.34e-07
#  1979XB    None  1979XB   -- 2065-12-16 2065-12-16               2.72e-09
#  1979XB    None  1979XB   -- 2101-12-14 2101-12-14               3.46e-09
#  1979XB    None  1979XB   -- 2113-12-14 2113-12-14               4.94e-07
#  1991BA    None  1991BA   -- 2075-01-20 2075-01-20               1.85e-09
#  1991BA    None  1991BA   -- 2077-01-19 2077-01-19               4.46e-09
#  1991BA    None  1991BA   -- 2078-01-19 2078-01-19              1.594e-06
#  1991BA    None  1991BA   -- 2089-01-19 2089-01-19               1.94e-08
#  1991BA    None  1991BA   -- 2091-01-19 2091-01-19               4.68e-10
#     ...     ...     ...  ...        ...        ...                    ...
# 2026BS7    None 2026BS7   -- 2107-10-08 2107-10-08               3.18e-09
# 2026BS7    None 2026BS7   -- 2099-10-06 2099-10-06               3.03e-08
# 2026BS7    None 2026BS7   -- 2098-10-05 2098-10-05               1.37e-09
# 2026BS7    None 2026BS7   -- 2097-10-06 2097-10-06               1.66e-07
# 2026BS7    None 2026BS7   -- 2086-10-05 2086-10-05               5.45e-08
# 2026BS7    None 2026BS7   -- 2076-10-05 2076-10-05                7.5e-10
# 2026BS7    None 2026BS7   -- 2064-10-05 2064-10-05               1.77e-07
# 2026BS7    None 2026BS7   -- 2113-10-06 2113-10-08             3.3854e-07
# 2026BS7    None 2026BS7   -- 2075-10-06 2075-10-06               8.92e-10
# 2026BZ5    None 2026BZ5   -- 2094-07-05 2094-07-07 1.0189000000000001e-08

# %% [markdown]
# ### Compare objects listed in NASA with those listed in ESA
# **Check objects**

# %%
# NASA_cum_ip_table
# ESA_cum_ip_table
NASA_cum_ip_table["both_listed"] = False
ESA_cum_ip_table["both_listed"] = False
NASA_cum_ip_table["both_event"] = False
ESA_cum_ip_table["both_event"] = False

for row in NASA_cum_ip_table:
    if str(row["des_chr"]) in ESA_cum_ip_table["des_chr"]:
        row["both_listed"] = True

for row in ESA_cum_ip_table:
    if str(row["des_chr"]) in NASA_cum_ip_table["des_chr"]:
        row["both_listed"] = True

# %% [markdown]
# **Check event date**<br>
# If both NASA and ESA list have the same object and approximately the same event date, give unique and the same event ID with format `{des_chr}_{date}`

# %%
NASA_event_ids = [""] * len(NASA_cum_ip_table)
ESA_event_ids = [""] * len(ESA_cum_ip_table)

i = 0
for row in NASA_cum_ip_table:
    if row["both_listed"]:
        idx = np.where(ESA_cum_ip_table["des_chr"] == row["des_chr"])[0]
        for f in idx:
            low_bound = datetime.strptime(row["date_start"],'%Y-%m-%d') - timedelta(days=event_range)
            high_bound = datetime.strptime(row["date_end"],'%Y-%m-%d') + timedelta(days=event_range)
            start_date = datetime.strptime(ESA_cum_ip_table[f]["date_start"],'%Y-%m-%d')
            end_date = datetime.strptime(ESA_cum_ip_table[f]["date_end"],'%Y-%m-%d')
            datetime.strptime(row["date_start"],'%Y-%m-%d')
            if (low_bound < start_date and start_date < high_bound) or (low_bound < end_date and end_date < high_bound):
                row["both_event"] = True
                ESA_cum_ip_table[f]["both_event"] = True
                NASA_event_ids[i] = f"{row["des_chr"]}_{row["date_start"]}"
                ESA_event_ids[f] = f"{row["des_chr"]}_{row["date_start"]}"
    i = i + 1

NASA_cum_ip_table["event_id"] = NASA_event_ids
ESA_cum_ip_table["event_id"] = ESA_event_ids

# %%
NASA_cum_ip_table
# Out:
# <Table length=22326>
# des_chr des_num   des    ... both_listed both_event      event_id
#   str9   object  str10   ...     bool       bool          str20
# ------- ------- -------- ... ----------- ---------- -----------------
#  1950DA   29075    29075 ...       False      False
#  1979XB    None  1979 XB ...        True       True 1979XB_2113-12-14
#  1979XB    None  1979 XB ...        True      False
#  1979XB    None  1979 XB ...        True      False
#  1979XB    None  1979 XB ...        True       True 1979XB_2056-12-12
#  1991BA    None  1991 BA ...        True      False
#  1991BA    None  1991 BA ...        True       True 1991BA_2027-01-19
#  1991BA    None  1991 BA ...        True       True 1991BA_2073-01-19
#  1991BA    None  1991 BA ...        True       True 1991BA_2075-01-19
#     ...     ...      ... ...         ...        ...               ...
# 2026CU1    None 2026 CU1 ...       False      False
# 2026CU1    None 2026 CU1 ...       False      False
# 2026CU1    None 2026 CU1 ...       False      False
# 2026CU1    None 2026 CU1 ...       False      False
# 2026CU1    None 2026 CU1 ...       False      False
# 2026CU1    None 2026 CU1 ...       False      False
# 2026CU1    None 2026 CU1 ...       False      False
# 2026CU1    None 2026 CU1 ...       False      False
# 2026CU1    None 2026 CU1 ...       False      False
# 2026CU1    None 2026 CU1 ...       False      False

# %%
ESA_cum_ip_table
# Out:
# <Table length=18106>
# des_chr des_num   des   name ... both_listed both_event      event_id
#   str9   object   str9  str8 ...     bool       bool          str20
# ------- ------- ------- ---- ... ----------- ---------- ------------------
#  1979XB    None  1979XB   -- ...        True       True  1979XB_2056-12-12
#  1979XB    None  1979XB   -- ...        True      False
#  1979XB    None  1979XB   -- ...        True      False
#  1979XB    None  1979XB   -- ...        True       True  1979XB_2113-12-14
#  1991BA    None  1991BA   -- ...        True       True  1991BA_2075-01-19
#  1991BA    None  1991BA   -- ...        True       True  1991BA_2077-01-19
#  1991BA    None  1991BA   -- ...        True       True  1991BA_2078-01-19
#  1991BA    None  1991BA   -- ...        True       True  1991BA_2089-01-19
#  1991BA    None  1991BA   -- ...        True      False
#     ...     ...     ...  ... ...         ...        ...                ...
# 2026BS7    None 2026BS7   -- ...        True       True 2026BS7_2107-10-07
# 2026BS7    None 2026BS7   -- ...        True      False
# 2026BS7    None 2026BS7   -- ...        True      False
# 2026BS7    None 2026BS7   -- ...        True       True 2026BS7_2097-10-06
# 2026BS7    None 2026BS7   -- ...        True       True 2026BS7_2086-10-05
# 2026BS7    None 2026BS7   -- ...        True      False
# 2026BS7    None 2026BS7   -- ...        True       True 2026BS7_2064-10-05
# 2026BS7    None 2026BS7   -- ...        True      False
# 2026BS7    None 2026BS7   -- ...        True      False
# 2026BZ5    None 2026BZ5   -- ...        True       True 2026BZ5_2094-07-07

# %% [markdown]
# **List-up by event id**<br>
# If only one of the 2 data set lists an event, the IP of the non-listed dataset will be `none`

# %%
des_chrs = []
des_nums = []
event_ids = []
ip_NASAs = []
ip_ESAs = []
v_infs = []

for row in NASA_cum_ip_table[NASA_cum_ip_table["both_event"]]:
    idx = np.where(ESA_cum_ip_table["event_id"] == row["event_id"])[0]
    for f in idx:
        des_chrs.append(row["des_chr"])
        des_nums.append(row["des_num"])
        event_ids.append(row["event_id"])
        ip_NASAs.append(row["cum_ip"])
        ip_ESAs.append(ESA_cum_ip_table[f]["cum_ip"])
        v_infs.append(row["v_inf"])
        break

for row in NASA_cum_ip_table[(NASA_cum_ip_table["both_event"] == False)]:
    des_chrs.append(row["des_chr"])
    des_nums.append(row["des_num"])
    event_ids.append(f"{row["des_chr"]}_{row["date_start"]}")
    ip_NASAs.append(row["cum_ip"])
    ip_ESAs.append(None)
    v_infs.append(row["v_inf"])

for row in ESA_cum_ip_table[(ESA_cum_ip_table["both_event"] == False)]:
    des_chrs.append(row["des_chr"])
    des_nums.append(row["des_num"])
    event_ids.append(f"{row["des_chr"]}_{row["date_start"]}")
    ip_NASAs.append(None)
    ip_ESAs.append(row["cum_ip"])
    v_infs.append(None)

NASA_ESA_ip_table = Table({
    "des_chr": des_chrs,
    "des_num": des_nums,
    "event_id": event_ids,
    "ip_NASA": ip_NASAs,
    "ip_ESA": ip_ESAs,
    "v_inf": v_infs
})

NASA_ESA_ip_table.sort("event_id")

NASA_ESA_ip_table.write(f'{output_PATH}/NASA_ESA_ip_table.csv', overwrite = True)
with open(f'{output_PATH}/workspace_NASA_ESA_ip_table.pkl', 'wb') as f:
    pickle.dump(NASA_ESA_ip_table, f)

NASA_ESA_ip_table
# Out:
# <Table length=28594>
# des_chr des_num      event_id      ...  ip_ESA       v_inf
#   str9   object       str20        ...  object       object
# ------- ------- ------------------ ... -------- ----------------
#  1950DA   29075  1950DA_2880-03-16 ...     None             14.1
#  1979XB    None  1979XB_2056-12-12 ... 2.34e-07 23.7606234552547
#  1979XB    None  1979XB_2065-12-16 ... 2.72e-09             None
#  1979XB    None  1979XB_2086-12-16 ...     None 23.7606234552547
#  1979XB    None  1979XB_2101-12-14 ... 3.46e-09             None
#  1979XB    None  1979XB_2102-12-16 ...     None 23.7606234552547
#  1979XB    None  1979XB_2113-12-14 ... 4.94e-07 23.7606234552547
#  1991BA    None  1991BA_2026-01-17 ... 2.55e-09             None
#  1991BA    None  1991BA_2027-01-19 ... 3.45e-09 16.7227981196217
#     ...     ...                ... ...      ...              ...
# 2026CU1    None 2026CU1_2076-02-29 ...     None 8.13169141778632
# 2026CU1    None 2026CU1_2079-03-01 ...     None 8.13169141778632
# 2026CU1    None 2026CU1_2081-03-01 ...     None 8.13169141778632
# 2026CU1    None 2026CU1_2087-03-02 ...     None 8.13169141778632
# 2026CU1    None 2026CU1_2088-03-01 ...     None 8.13169141778632
# 2026CU1    None 2026CU1_2090-03-01 ...     None 8.13169141778632
# 2026CU1    None 2026CU1_2093-03-01 ...     None 8.13169141778632
# 2026CU1    None 2026CU1_2094-03-01 ...     None 8.13169141778632
# 2026CU1    None 2026CU1_2097-03-01 ...     None 8.13169141778632
# 2026CU1    None 2026CU1_2100-03-01 ...     None 8.13169141778632

# %% [markdown]
# ### Plot result
# Scatter plot of the IP by NASA vs the IP by ESA. None will be handled as 0 in the plot.

# %%
plt.figure(figsize=(6,6))
plt.scatter([0 if x is None else x for x in NASA_ESA_ip_table["ip_NASA"]],[0 if x is None else x for x in NASA_ESA_ip_table["ip_ESA"]])
plt.xlabel("IP by NASA")
plt.ylabel("IP by ESA")
plt.xscale("log")
plt.yscale("log")
plt.xlim(1e-12,0.012)
plt.ylim(1e-12,0.012)
plt.gca().invert_xaxis()
plt.gca().invert_yaxis()
plt.show()

# %%
eps = 1e-14

x_raw = np.array([0 if x is None else x for x in NASA_ESA_ip_table["ip_NASA"]], dtype=float)
y_raw = np.array([0 if x is None else x for x in NASA_ESA_ip_table["ip_ESA"]], dtype=float)

x_plot = np.where(x_raw <= 0, eps, x_raw)
y_plot = np.where(y_raw <= 0, eps, y_raw)
zero_mask = (x_raw <= 0) | (y_raw <= 0)

plt.figure(figsize=(6,6))
plt.scatter(x_plot, y_plot, s=25, alpha=0.7)
plt.scatter(
    x_plot[zero_mask],
    y_plot[zero_mask],
    marker=".",
    color="red",
    # s=60,
    label="IP of one party = 0"
)

plt.xlabel("IP by NASA")
plt.ylabel("IP by ESA")

plt.xscale("log")
plt.yscale("log")

plt.xlim(1, eps)
plt.ylim(1, eps)

plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
